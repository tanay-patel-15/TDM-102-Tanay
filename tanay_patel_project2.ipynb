# %% [markdown]
# # Project 2 -- Tanay Patel

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# - ***Link to AI Chat History***: Please share a link to your chat if you used AI (ex. ChatGPT Shared Links)
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Question 1

# %%
import pandas as pd

# %%
myDF = pd.read_csv('/anvil/projects/tdm/data/movies_and_tv/rotten_tomatoes_movies.csv')

# %%
myDF.head()
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
myDF.shape
# Out:
# (16638, 23)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
myDF.head()
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %% [markdown]
# ## There are 16638 rows and 23 columns in this data set.

# %%
myDF['rating'].value_counts()
# Out:
# rating
# R         6136
# NR        4862
# PG-13     2885
# PG        2062
# G          652
# NC17        37
# PG-13)       3
# R)           1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
mycounts = myDF['rating'].value_counts()

# %%
plt.bar(mycounts.index, mycounts, width = 0.2, color = 'orange')
plt.title('Rating Counts of different categories')
plt.xlabel('Rating name')
plt.ylabel('Rating count')
# Out:
# Text(0, 0.5, 'Rating count')

# %% [markdown]
# In question 1, first we import the rotten tomatoes dataset and then changed the max columns limit to none and max rows limit to 10 as shown in the video. Then we finally we plotted a plot for rating counts using the value counts of the rating column stored in the variable 'mycounts' and gave it a title, axis labels and some other customizations like color and bar width.

# %% [markdown]
# ## Question 2

# %%
myDF['rating'].value_counts()
# Out:
# rating
# R         6136
# NR        4862
# PG-13     2885
# PG        2062
# G          652
# NC17        37
# PG-13)       3
# R)           1
# Name: count, dtype: int64

# %%
myDF['directors'].value_counts()
# Out:
# directors
# Alfred Hitchcock                                                                                                                                                                          36
# Woody Allen                                                                                                                                                                               36
# Clint Eastwood                                                                                                                                                                            35
# Steven Spielberg                                                                                                                                                                          32
# Sidney Lumet                                                                                                                                                                              30
# ...

# %%
myDF['studio_name'].value_counts()
# Out:
# studio_name
# Paramount Pictures                497
# Warner Bros. Pictures             492
# Universal Pictures                469
# 20th Century Fox                  414
# IFC Films                         398
#                                  ...
# FEARnet                             1
# HandMade Films                      1
# Herts-Lion International Corp.      1
# PRC Pictures Inc.                   1
# Kagan Company Radio Telegraph       1
# Name: count, Length: 2886, dtype: int64

# %%
len(myDF['rating'].value_counts())
# Out:
# 8

# %%
len(myDF['directors'].value_counts())
# Out:
# 8314

# %%
len(myDF['studio_name'].value_counts())
# Out:
# 2886

# %% [markdown]
# ## Alfred Hitchcock and Woody Allen have directed the most projects.

# %% [markdown]
# ## Paramount Pictures has produced the most films.

# %% [markdown]
# In question 2, we take value counts of other columns like director and studio_name. We also learnt that we can use len() function to count of the different types of values existing in a column and then learned the use of Ascending=True in value_counts() to sort the output in an ascending manner.

# %% [markdown]
# ## Question 3

# %%
myDF[myDF['genre']== "Comedy"].head()
# Out:
#                        rotten_tomatoes_link           movie_title  \
# 1                                /m/0878835           Please Give
# 23                    /m/10004050-bandwagon             Bandwagon
# 27  /m/10004232-10004232-tale_of_two_pizzas  A Tale of Two Pizzas
# 29           /m/10004352-going_the_distance    Going the Distance
# 53                              /m/10006270       When Do We Eat?
#
#                                            movie_info  \
# 1   Kate has a lot on her mind. There's the ethics...
# 23  A group of hard-working, young North Carolinia...
# 27  Two warring families are brought together by l...
# 29  Delightfully raunchy wit drives this teen come...
# 53  This is the story of the world's fastest Passo...
#
#                                     critics_consensus  \
# 1   Nicole Holofcener's newest might seem slight i...
# 23                                                NaN
# 27                                                NaN
# ...

# %%
myDF[myDF['genre'] == "Comedy"].shape[0]
# Out:
# 1202

# %%
myDF['genre'].str.contains("Comedy", na=False).sum()
# Out:
# np.int64(5385)

# %%
myDF[
    myDF['genre'].str.contains("Comedy", na=False)
].head()
# Out:
#     rotten_tomatoes_link                                        movie_title  \
# 0             /m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 1             /m/0878835                                        Please Give
# 2                  /m/10                                                 10
# 8     /m/10002008-charly                          Charly (A Heartbeat Away)
# 14  /m/1000253-adams_rib                                         Adam's Rib
#
#                                            movie_info  \
# 0   A teenager discovers he's the descendant of a ...
# 1   Kate has a lot on her mind. There's the ethics...
# 2   Blake Edwards' 10 stars Dudley Moore as George...
# 8   Sam Roberts thinks he has all the answers: the...
# 14  Written by Ruth Gordon and Garson Kanin, Adam'...
#
#                                     critics_consensus  \
# 0   Though it may seem like just another Harry Pot...
# 1   Nicole Holofcener's newest might seem slight i...
# ...

# %%
myDF[
    myDF['genre'].str.contains("Romance", na=False)
].head()
# Out:
#                    rotten_tomatoes_link                   movie_title  \
# 2                                 /m/10                            10
# 8                    /m/10002008-charly     Charly (A Heartbeat Away)
# 14                 /m/1000253-adams_rib                    Adam's Rib
# 20  /m/1000355-adventures_of_robin_hood  The Adventures of Robin Hood
# 25       /m/10004209-tristan_and_isolde              Tristan & Isolde
#
#                                            movie_info  \
# 2   Blake Edwards' 10 stars Dudley Moore as George...
# 8   Sam Roberts thinks he has all the answers: the...
# 14  Written by Ruth Gordon and Garson Kanin, Adam'...
# 20  In order to avoid the material copyrighted by ...
# 25  In the medieval legend of Tristan and Isolde, ...
#
#                                     critics_consensus  \
# 2                                                 NaN
# 8                                                 NaN
# ...

# %% [markdown]
# In question 3, we learnt to get all the rows with a certain value in the a certain column. First we see a result where it is exclusively that value in that column. Then we use .str.contains() function so that it doesn't give us a result where the value is exclusive. We applied these two functions for two different values in the genre column namely 'Comedy' and 'Romance'.

# %% [markdown]
# ## Question 4

# %%
myDF.loc[myDF['rating'] == 'R)', 'rating'] = 'R'
myDF.loc[myDF['rating'] == 'PG-13)', 'rating'] = 'PG-13'

# %%
myDF['rating'].value_counts()
# Out:
# rating
# R        6137
# NR       4862
# PG-13    2888
# PG       2062
# G         652
# NC17       37
# Name: count, dtype: int64

# %%
myDF['tomatometer_status'].value_counts()
# Out:
# tomatometer_status
# Rotten             7233
# Fresh              6448
# Certified Fresh    2957
# Name: count, dtype: int64

# %% [markdown]
# ## Rotten status was given the most to films

# %%
pd.crosstab(myDF['rating'], myDF['tomatometer_status'])
# Out:
# tomatometer_status  Certified Fresh  Fresh  Rotten
# rating
# G                               124    336     192
# NC17                              7     19      11
# NR                              576   3081    1205
# PG                              376    753     933
# PG-13                           563    593    1732
# R                              1311   1666    3160

# %% [markdown]
# In question 4, first we clean the data regarding values in rating column created by typos and merge them into supposed to be categories. We also use the value_counts() function on the tomatometer_status column. We also used the cleaned data in rating column and the tomatometer_status column to create a cross tabulation of those two columns.

# %% [markdown]
# ## Question 5

# %%
myDF['joined_reviews'] = myDF['rating'] + " " + myDF['tomatometer_status']

# %%
myDF['joined_reviews'].value_counts()
# Out:
# joined_reviews
# R Rotten                3160
# NR Fresh                3081
# PG-13 Rotten            1732
# R Fresh                 1666
# R Certified Fresh       1311
#                         ...
# G Rotten                 192
# G Certified Fresh        124
# NC17 Fresh                19
# NC17 Rotten               11
# NC17 Certified Fresh       7
# Name: count, Length: 18, dtype: int64

# %% [markdown]
# ## R Rotten pairing has the most counts in the joined_reviews column

# %%
myDF['joined_reviews'].value_counts().shape
# Out:
# (18,)

# %%
subset_df = myDF[(myDF["rating"] == "PG") & (myDF["tomatometer_status"] == "Certified Fresh")]

# %%
subset_df.head()
# Out:
#                     rotten_tomatoes_link                   movie_title  \
# 20   /m/1000355-adventures_of_robin_hood  The Adventures of Robin Hood
# 52              /m/1000626-all_about_eve                 All About Eve
# 94                /m/10008507-deep_water                    Deep Water
# 134             /m/10009001-the_freshman                  The Freshman
# 307                 /m/1002352-big_sleep                 The Big Sleep
#
#                                             movie_info  \
# 20   In order to avoid the material copyrighted by ...
# 52   Based on the story The Wisdom of Eve by Mary O...
# 94   Co-directors Louise Osmond and Jerry Rothwell'...
# 134  This is the story of a college freshman so eag...
# 307  The definitive Humphrey Bogart/Lauren Bacall v...
#
#                                      critics_consensus  \
# 20   Errol Flynn thrills as the legendary title cha...
# 52   Smart, sophisticated, and devastatingly funny,...
# ...

# %%
myDF[myDF["movie_title"] == 'Star Trek']
# Out:
#       rotten_tomatoes_link movie_title  \
# 13001      /m/star_trek_11   Star Trek
#
#                                               movie_info  \
# 13001  Mission: Impossible III director and Alias cre...
#
#                                        critics_consensus  \
# 13001  Star Trek reignites a classic franchise with a...
#
#                                         poster_image_url rating  \
# 13001  https://resizing.flixster.com/bvoSOPJQ_ku4LCqC...  PG-13
#
#                                                    genre    directors  \
# 13001  Action & Adventure, Drama, Science Fiction & F...  J.J. Abrams
#
#                                              writers  \
# 13001  Gene Roddenberry, Alex Kurtzman, Roberto Orci
#
#                                                     cast in_theaters_date  \
# 13001  Chris Pine, Zachary Quinto, Leonard Nimoy, Kar...       2009-05-07
#
#       on_streaming_date  runtime_in_minutes studio_name tomatometer_status  \
# ...

# %%
myDF[myDF["movie_title"] == 'Inception']
# Out:
#      rotten_tomatoes_link movie_title  \
# 7864         /m/inception   Inception
#
#                                              movie_info  \
# 7864  Visionary filmmaker Christopher Nolan (Memento...
#
#                                       critics_consensus  \
# 7864  Smart, innovative, and thrilling, Inception is...
#
#                                        poster_image_url rating  \
# 7864  https://resizing.flixster.com/cZVU45vSaFFv0WGc...  PG-13
#
#                                                   genre          directors  \
# 7864  Action & Adventure, Drama, Mystery & Suspense,...  Christopher Nolan
#
#                 writers                                               cast  \
# 7864  Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...
#
#      in_theaters_date on_streaming_date  runtime_in_minutes  \
# 7864       2010-07-16        2010-12-07               148.0
#
#                 studio_name tomatometer_status  tomatometer_rating  \
# ...

# %% [markdown]
# In question 5, we make a joined_reviews column of the cleaned ratings column and the tomatometer_status column.
# make a subset of myDF where all the rows have PG as rating and Certified Fresh as the tomatometer status. Lastly, we find two rows where the movie titles matches two of my favorite movies.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
