# %% [markdown]
# # Project 1 -- Tanay Patel

# %% [markdown]
# **TA Help:** (for instance) John Smith, Alice Jones, etc., list names of any TAs who helped you
#
# - For example: Help with figuring out how to write a function (describe the tasks that they helped you with)
#
# **Collaboration:** My Friend in CS, My Uncle, Another Student, etc., list names of any other people who helped you
#
# (describe the tasks that they helped you with)
# - For example: helped figuring out how to load the dataset.
# - Another example: helped debug error with my plot.
#
# **Internet Resources:** Stack Exchange, Stack Overflow, etc.
#
# (describe any information that you learned from internet resources, including the URLs)
# - data frames in Pandas versus R from StackOverflow  https://stackoverflow.com/questions/8991709/why-were-pandas-merges-in-python-faster-than-data-table-merges-in-r-in-2012
#
# **ChatGPT, Gemini, Claude, etc:** Any language models or generative AI chatbots that helped you.
#
# (if you used any such tools, please tell us here)
# - For example:  I asked ChatGPT how to define a new data frames
# - Another example:  Gemini told me how to make a function for sorting my data
#
# - ***Link to AI Chat History***: Please share a link to your chat if you used AI (ex. ChatGPT Shared Links)
# **OVERALL MESSAGE:** Any time that you used anything except your brain to solve the questions in these projects, you need to disclose such resources at the start of the project, with details about your usage of the tools.
#
# **YOUR OWN WORK:** Even when you utilize other resources, do NOT just copy and paste.  Write all explanations in your own words, using several sentences in English, which are understandable and which you wrote (and did not just copy and paste).

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
myDF.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/olympics/athlete_events.csv")
myDF.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
myDF.head(12)
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %% [markdown]
# In this question we learn how to create a data frame in Python as compared to R that we learned last semester. First we load the airports dataset to learn how to make a data frame and then we load the Olympics Athlete Events data frame on our own and then display the first twelve rows of that.

# %% [markdown]
# ## Question 2

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
myDF.shape
# Out:
# (3376, 7)

# %%
myDF.tail()
# Out:
#      iata                    airport         city state country        lat  \
# 3371  ZEF            Elkin Municipal        Elkin    NC     USA  36.280024
# 3372  ZER  Schuylkill Cty/Joe Zerbey   Pottsville    PA     USA  40.706449
# 3373  ZPH      Zephyrhills Municipal  Zephyrhills    FL     USA  28.228065
# 3374  ZUN                 Black Rock         Zuni    NM     USA  35.083227
# 3375  ZZV       Zanesville Municipal   Zanesville    OH     USA  39.944458
#
#             long
# 3371  -80.786069
# 3372  -76.373147
# 3373  -82.155916
# 3374 -108.791777
# 3375  -81.892105

# %%
myDF[(myDF['city'] == 'New York') & (myDF['state'] == 'NY')]
# Out:
#      iata                                    airport      city state country  \
# 589   6N5                         E 34th St Heliport  New York    NY     USA
# 590   6N7                 New York Skyports Inc. SPB  New York    NY     USA
# 1915  JFK                        John F Kennedy Intl  New York    NY     USA
# 1929  JRA  Port Authority-W 30th St Midtown Heliport  New York    NY     USA
# 1930  JRB       Downtown Manhattan/Wall St. Heliport  New York    NY     USA
# 2061  LGA                                  LaGuardia  New York    NY     USA
#
#             lat       long
# 589   40.742602 -73.972083
# 590   40.733991 -73.972916
# 1915  40.639751 -73.778926
# 1929  40.754546 -74.007084
# 1930  40.701214 -74.009028
# 2061  40.777243 -73.872609

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/olympics/athlete_events.csv")
myDF.shape
# Out:
# (271116, 15)

# %%
myDF.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
myDF[(myDF['Team'] == 'Jamaica')
& (myDF['Season'] == 'Winter')
& (myDF['Year'] == 1988) 
& (myDF['Sport'] == 'Bobsleigh')]
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 91083    46160             Devon Desmond Harris   M  23.0   178.0    97.0
# 229854  115398  Nelson Christian "Chris" Stokes   M  24.0   189.0    90.0
# 229860  115400           Dudley Clifford Stokes   M  25.0   183.0    89.0
# 229861  115400           Dudley Clifford Stokes   M  25.0   183.0    89.0
# 259694  130007                    Michael White   M  23.0   182.0   107.0
# 259695  130007                    Michael White   M  23.0   182.0   107.0
#
#            Team  NOC        Games  Year  Season     City      Sport  \
# 91083   Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 229854  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 229860  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 229861  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# 259694  Jamaica  JAM  1988 Winter  1988  Winter  Calgary  Bobsleigh
# ...

# %% [markdown]
# In Question 2, first we learn how to how to get the dimensions of a data frame using myDF.shape and then we use that function to find the dimensions of both of our data sets. Further we learn how to extract filtered information using "myDF[(myDF['city'] == 'New York') & (myDF['state'] == 'NY')]" this format and we use similar syntax for the Olympics Athletes Events data set and find all the athletes who participated in the Bobsleigh race in the Winter 1988 Olympics representing Jamaica.

# %% [markdown]
# ## Question 3

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")

# %%
myDF['state']
# Out:
# 0       MS
# 1       TX
# 2       CO
# 3       NY
# 4       FL
#         ..
# 3371    NC
# 3372    PA
# 3373    FL
# 3374    NM
# 3375    OH
# Name: state, Length: 3376, dtype: object

# %%
myDF['state'].value_counts()
# Out:
# state
# AK    263
# TX    209
# CA    205
# OK    102
# OH    100
# FL    100
# GA     97
# NY     97
# MI     94
# MN     89
# IL     88
# WI     84
# KS     78
# IA     78
# MO     74
# AR     74
# NE     73
# AL     73
# NC     72
# MS     72
# MT     71
# PA     71
# TN     70
# IN     65
# WA     65
# AZ     59
# OR     57
# SD     57
# LA     55
# SC     52
# ND     52
# NM     51
# KY     50
# CO     49
# VA     47
# ID     37
# UT     35
# NJ     35
# ME     34
# NV     32
# WY     32
# MA     30
# WV     24
# MD     18
# HI     16
# CT     15
# NH     14
# VT     13
# PR     11
# RI      6
# VI      5
# DE      5
# CQ      4
# AS      3
# DC      1
# GU      1
# Name: count, dtype: int64

# %%
mycounts = myDF['state'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 5 artists>

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/olympics/athlete_events.csv")

# %%
mycounts = myDF['Team'].value_counts().head()

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# In question 3, we learn how to count the number of times a value appears in the column. Then we use head() to get the top 5 value occurences and then store that in a variable and use that variable to plot a graph by using pyplot from matplotlib. We use the airports dataset to learn and then make a graph of the Olympics Athlete Events dataset on our own.

# %% [markdown]
# ## Question 4

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/restaurant/vendors.csv")

# %%
myDF.head()
# Out:
#    id  authentication_id  latitude  longitude vendor_category_en  \
# 0   4           118597.0 -0.588596   0.754434        Restaurants
# 1  13           118608.0 -0.471654   0.744470        Restaurants
# 2  20           118616.0 -0.407527   0.643681        Restaurants
# 3  23           118619.0 -0.585385   0.753811        Restaurants
# 4  28           118624.0  0.480602   0.552850        Restaurants
#
#    vendor_category_id  delivery_charge  serving_distance  is_open  \
# 0                 2.0              0.0               6.0      1.0
# 1                 2.0              0.7               5.0      1.0
# 2                 2.0              0.0               8.0      1.0
# 3                 2.0              0.0               5.0      1.0
# 4                 2.0              0.7              15.0      1.0
#
#        OpeningTime  ... open_close_flags                 vendor_tag  \
# 0  11:00AM-11:30PM  ...              1.0  2,4,5,8,91,22,12,24,16,23
# ...

# %%
myDF['vendor_category_en'].value_counts()
# Out:
# vendor_category_en
# Restaurants       88
# Sweets & Bakes    12
# Name: count, dtype: int64

# %% [markdown]
# For question 4, we simply reiterate what we learned in question 3 about displaying different value occurences as we can see two types of vendors are displayed there: Restaurants and 'Sweets & Bakes'.

# %% [markdown]
# ## Question 5

# %%
mycounts = myDF['vendor_category_en'].value_counts().head()

# %%
plt.bar(mycounts.index, mycounts)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# For question 5, we simply make a barplot of the number of occurences for each type of vendor for the vendors data set.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
